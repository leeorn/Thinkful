# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
data_address = "WELLCOME_APCspend2013_forThinkful.csv"

# %%
file = pd.read_csv(data_address, encoding = "ISO-8859-1")

# %%
file.head()
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS              J Med Chem
# 3    23438330 PMC3646402       ACS              J Med Chem
# 4   23438216 PMC3601604        ACS              J Org Chem
#
#                                        Article title  \
# 0  Reduced parahippocampal cortical thickness in ...
# 1  Structural characterization of a Model Gram-ne...
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...
# 3  Orvinols with mixed kappa/mu opioid receptor a...
# 4  Regioselective opening of myo-inositol orthoes...
#
#   COST (£) charged to Wellcome (inc VAT when charged)
# 0                                              £0.00
# 1                                           £2381.04
# 2                                            £642.56
# 3                                            £669.64
# 4                                            £685.88

# %%
# loading the data into a new DF and omitting columns that have the values listed below (garbage)
missing_values = ["n/a", "n\a", "--", "na"]
filtered_file = pd.read_csv(data_address, na_values=missing_values, encoding = "ISO-8859-1")

# %%
# Dropping any row that has a missing value (in any of the columns) and show first 10 from the cleaned data
clean_file = filtered_file.dropna()
clean_file.head(10)
# Out:
#                PMID/PMCID                                     Publisher  \
# 1              PMC3679557                                           ACS
# 2   23043264  PMC3506128                                            ACS
# 3     23438330 PMC3646402                                           ACS
# 4    23438216 PMC3601604                                            ACS
# 5              PMC3579457                                           ACS
# 6              PMC3709265                                           ACS
# 7    23057412 PMC3495574                                            ACS
# 8       PMCID: PMC3780468  ACS (Amercian Chemical Society) Publications
# 9       PMCID: PMC3621575  ACS (Amercian Chemical Society) Publications
# 10      PMCID: PMC3739413  ACS (Amercian Chemical Society) Publications
#
#                                    Journal title  \
# 1                              Biomacromolecules
# 2                                     J Med Chem
# 3                                     J Med Chem
# 4                                     J Org Chem
# 5                 Journal of Medicinal Chemistry
# 6                   Journal of Proteome Research
# 7                                      Mol Pharm
# 8                           ACS Chemical Biology
# 9                           ACS Chemical Biology
# 10  Journal of Chemical Information and Modeling
#
#                                         Article title  \
# 1   Structural characterization of a Model Gram-ne...
# 2   Fumaroylamino-4,5-epoxymorphinans and related ...
# 3   Orvinols with mixed kappa/mu opioid receptor a...
# 4   Regioselective opening of myo-inositol orthoes...
# 5   Comparative Structural and Functional Studies ...
# 6   Mapping Proteolytic Processing in the Secretom...
# 7   Quantitative silencing of EGFP reporter gene b...
# 8   A Novel Allosteric Inhibitor of the Uridine Di...
# 9   Chemical proteomic analysis reveals the drugab...
# 10  Locating Sweet Spots for Screening Hits and Ev...
#
#    COST (£) charged to Wellcome (inc VAT when charged)
# 1                                            £2381.04
# 2                                             £642.56
# 3                                             £669.64
# 4                                             £685.88
# 5                                            £2392.20
# 6                                            £2367.95
# 7                                             £649.33
# 8                                            £1294.59
# 9                                            £1294.78
# 10                                           £1329.69

# %%
# Print the 5 most popular Journal titles
print(clean_file["Journal title"].value_counts().head())
# Out:
# PLoS One                                           91
# PLoS ONE                                           62
# Journal of Biological Chemistry                    47
# Nucleic Acids Research                             20
# Proceedings of the National Academy of Sciences    19
# Name: Journal title, dtype: int64

# %%
# change the last coulmn name (for easier access)
clean_file = clean_file.rename(index=str, columns={"COST (£) charged to Wellcome (inc VAT when charged)": "cost"})

# cut the money sign and make it an int for further calculation
clean_file['cost'] = clean_file['cost'].map(lambda x: ''.join([i for i in x if i.isdigit()]))

# print to see the head of the data
clean_file.head()

clean_file["cost"] = clean_file["cost"].astype(int)

#print(type(clean_file["cost"][0]))

# %%
# group by journal name and find mean, median and std of each
journal_df = clean_file.groupby("Journal title")
journal_df.agg(['mean', "median", "std"])

# *NaN value means
# Out:
#                                                             cost              \
#                                                             mean      median
# Journal title
# ACS Chemical Biology                                1.535965e+05    129468.5
# ACS Chemical Neuroscience                           1.186800e+05    118680.0
# ACS NANO                                            6.428900e+04     64289.0
# ACS Nano                                            6.933900e+04     69339.0
# ACTA F                                              7.549000e+04     75490.0
# AGE                                                 2.002000e+05    200200.0
# AIDS                                                2.059307e+05    196863.0
# AIDS Behav                                          1.834770e+05    183477.0
# AIDS Care                                           2.189170e+05    218917.0
# AIDS Journal                                        2.015720e+05    201572.0
# AIDS Research and Therapy                           1.240000e+05    124000.0
# AIDS UK                                             1.836920e+05    183692.0
# Academy of Nutrition and Dietetics                  2.379540e+05    237954.0
# Acta Crystallographica Section D,  Biological C...  7.714200e+04     77142.0
# Acta Crystallographica Section D: Biological Cr...  7.737400e+04     77374.0
# Acta Crystallographica Section F: Structural Bi...  7.966350e+04     79663.5
# Acta Crystallographica, Section D                   7.571800e+04     75718.0
# Acta Crystallography D                              7.741900e+04     77419.0
# Acta D                                              7.501600e+04     75016.0
# Acta Dermato Venereologica                          6.539600e+04     65396.0
# Acta Diabetologica                                  2.336280e+05    233628.0
# Acta Neuropathol                                    1.901040e+05    190104.0
# Acta Neuropathologica                               2.299590e+05    229959.0
# Acta Opthalmologica                                 2.270160e+05    227016.0
# Acta Physiol                                        1.991500e+05    199150.0
# Addiction                                           2.136225e+05    213622.5
# Age                                                 2.338280e+05    233828.0
# Age and Ageing                                      2.040000e+05    204000.0
# Aging Cell                                          1.970570e+05    197057.0
# Aids Care                                           2.399280e+05    239928.0
# ...                                                          ...         ...
# Traffic                                             2.081474e+05    223922.0
# Transactions of the Royal Society of Tropical M...  1.524080e+05    152408.0
# Translational Psychiatry                            2.880000e+05    288000.0
# Trends in Cognitive Science                         2.340630e+05    234063.0
# Trends in Genetics                                  2.370935e+05    237093.5
# Trends in Microbiology                              2.291330e+05    229133.0
# Trends in Molecular Medicine                        2.248330e+05    224833.0
# Trends in Neuroscience                              2.402810e+05    240281.0
# Trends in Neurosciences                             2.426960e+05    242696.0
# Trials                                              2.509090e+07    125325.0
# Trials                                              1.165000e+05    116500.0
# Trop Med Int Health                                 1.834770e+05    183477.0
# Tropical Animal Health & Production                 2.054780e+05    205478.0
# Tropical Medicine and International Health          1.821932e+05    187032.0
# Tuberculosis                                        2.161255e+05    216125.5
# Urolithiasis                                        1.112400e+05    111240.0
# Vaccine                                             1.623394e+05    144838.0
# Vascular Pharmacology                               2.352530e+05    235253.0
# Veterinary Microbiology                             2.451490e+05    245149.0
# Veterinary Parasitology                             2.488170e+05    248817.0
# Veterinary Record                                   2.040000e+05    204000.0
# Veterinary Research                                 9.930000e+02       993.0
# Virology                                            1.928505e+05    192850.5
# Virology Journal                                    1.242000e+05    124200.0
# Virus Research                                      1.947090e+05    194709.0
# Vision Research                                     5.007276e+07  50072759.0
# Visual Neuroscience                                 2.034000e+05    203400.0
# Zoonoses and Public Health                          2.272150e+05    227215.0
# genesis: Journal of Genetics                        2.376400e+05    237640.0
# mBio                                                1.355130e+05    135513.0
#
#
#                                                              std
# Journal title
# ACS Chemical Biology                                5.006709e+04
# ACS Chemical Neuroscience                                    NaN
# ACS NANO                                                     NaN
# ACS Nano                                                     NaN
# ACTA F                                                       NaN
# AGE                                                          NaN
# AIDS                                                2.810680e+04
# AIDS Behav                                                   NaN
# AIDS Care                                           6.161728e+03
# AIDS Journal                                                 NaN
# AIDS Research and Therapy                                    NaN
# AIDS UK                                             0.000000e+00
# Academy of Nutrition and Dietetics                           NaN
# Acta Crystallographica Section D,  Biological C...           NaN
# Acta Crystallographica Section D: Biological Cr...           NaN
# Acta Crystallographica Section F: Structural Bi...  1.560585e+03
# Acta Crystallographica, Section D                            NaN
# Acta Crystallography D                                       NaN
# Acta D                                                       NaN
# Acta Dermato Venereologica                                   NaN
# Acta Diabetologica                                           NaN
# Acta Neuropathol                                             NaN
# Acta Neuropathologica                               6.875906e+03
# Acta Opthalmologica                                          NaN
# Acta Physiol                                                 NaN
# Addiction                                           3.064813e+04
# Age                                                          NaN
# Age and Ageing                                               NaN
# Aging Cell                                                   NaN
# Aids Care                                           0.000000e+00
# ...                                                          ...
# Traffic                                             3.576396e+04
# Transactions of the Royal Society of Tropical M...           NaN
# Translational Psychiatry                            0.000000e+00
# Trends in Cognitive Science                                  NaN
# Trends in Genetics                                  3.995153e+02
# Trends in Microbiology                                       NaN
# Trends in Molecular Medicine                                 NaN
# Trends in Neuroscience                                       NaN
# Trends in Neurosciences                                      NaN
# Trials                                              4.993934e+07
# Trials                                                       NaN
# Trop Med Int Health                                          NaN
# Tropical Animal Health & Production                          NaN
# Tropical Medicine and International Health          1.705214e+04
# Tuberculosis                                        2.281339e+04
# Urolithiasis                                                 NaN
# Vaccine                                             3.948215e+04
# Vascular Pharmacology                                        NaN
# Veterinary Microbiology                                      NaN
# Veterinary Parasitology                                      NaN
# Veterinary Record                                            NaN
# Veterinary Research                                          NaN
# Virology                                            6.978508e+04
# Virology Journal                                             NaN
# Virus Research                                               NaN
# Vision Research                                     7.060764e+07
# Visual Neuroscience                                          NaN
# Zoonoses and Public Health                                   NaN
# genesis: Journal of Genetics                                 NaN
# mBio                                                         NaN
#
# [902 rows x 3 columns]
