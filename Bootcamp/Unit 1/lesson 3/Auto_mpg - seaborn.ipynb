# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
auto = sns.load_dataset("mpg")

# %%
auto.head(10)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
# 5  15.0          8         429.0       198.0    4341          10.0
# 6  14.0          8         454.0       220.0    4354           9.0
# 7  14.0          8         440.0       215.0    4312           8.5
# 8  14.0          8         455.0       225.0    4425          10.0
# 9  15.0          8         390.0       190.0    3850           8.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# ...

# %% [markdown]
# ## Drills
# * Choose one variable and plot that variable four different ways.
# ??

# %% [markdown]
# * Choose two continuous variables, and plot them three different ways.

# %%
sns.set(style="whitegrid")

g = sns.catplot(x="weight", y="horsepower", data=auto, height=6, palette="muted")

# %%
sns.residplot(auto["weight"], auto["horsepower"], lowess = True, color = "b")
plt.show()

# %%
data = pd.DataFrame(auto["weight"], auto["horsepower"])
sns.lineplot(data=data )

# %% [markdown]
# * Choose one continuous variable and one categorical variable, and plot them six different ways.

# %%
sns.lmplot(x="model_year", y="horsepower", data=auto)
plt.show()

# %%
sns.boxplot(x="model_year", y="horsepower", data=auto)

# %%
sns.lineplot(data=auto, x="model_year", y="horsepower")
plt.show()

# %%
sns.barplot(x=auto["model_year"], y=auto["horsepower"])
plt.show()

# %%
sns.scatterplot(data=auto, x="model_year", y="horsepower")
plt.show()

# %%
sns.violinplot(data=auto, x="model_year", y="horsepower", inner="points")

# %% [markdown]
# ### As an optional challenge, find a dataset with at least four continuous variables and one categorical variable. Create one master plot that gives insight into the variables and their interrelationships, including:
#
# * Probability distributions
# * Bivariate relationships
# * Whether the distributions or the relationships vary across groups
#
# Continuous variables: MPG. horsepower, weight, acceleration
# categorical variable: Model year

# %%
data = {"MPG": auto["mpg"], "horsepower": auto["horsepower"], "weight": auto["weight"], "acceleration": auto["acceleration"]}
contin_df = pd.DataFrame(data)
#sns.lineplot(data=contin_df)

# %%
sns.boxplot(data=contin_df)

# %%
data = {"MPG": auto["mpg"], "horsepower": auto["horsepower"], "weight": auto["weight"], "acceleration": auto["acceleration"]}
df = pd.DataFrame({"years": (auto["model_year"])})

# %%
g = sns.pairplot(auto, height=5.5,
                 x_vars=["model_year"],
                y_vars=["mpg", "horsepower", "weight", "acceleration"])
